# %%
import matplotlib.pyplot as plt
import numpy as np
from copulas import plot_random_variable, plot_amh, plot_contour, plot_surface

# %%
# theta is in [-1, 1]
theta = 0.9

# %%
def c(u, v):
    return (u * v) / (1 - (theta * (1 - u) * (1 - v)))

# %%
plot_contour(c, 'Ali-Mikhail-Haq')

# %%
plot_surface(c, 'Ali-Mikhail-Haq')

# %%
u = np.random.default_rng().uniform(0, 1, 5000)
t = np.random.default_rng().uniform(0, 1, 5000)

# %%
plot_random_variable(u, t)

# %%
plot_amh([0.1, 0.8, 0.99], u, t)
